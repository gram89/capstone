# %%
#import dependencies

import pandas as pd
from time import time, sleep
from requests import Session
from bs4 import BeautifulSoup as soup

# %%
#initiate the loading process
t1 = time()
main_session = Session()

# %%
#create a dictionary and a list for all pages
listing_info=[]

for i in range(1,200):
    url = f"https://listing.ca/mls/?..........{i}..$"
    print(f"Scraping {url}")
    resp = main_session.get(url)
    #time.sleep(3)
    listing_ca_page = soup(resp.content, 'html.parser')
    #extracting information
    prop_address = listing_ca_page.find_all("div",{"class","slt_address"})
    prop_beds = listing_ca_page.find_all("div",{"class","slt_beds"})
    prop_baths = listing_ca_page.find_all("div",{"class","slt_baths"})
    prop_price = listing_ca_page.find_all("div",{"class","slt_price"})
    j=0
    for j in range(0,len(prop_address)):
        add = prop_address[j].text
        price = prop_price[j].text
        beds = prop_beds[j].text
        baths = prop_baths[j].text
    
        listing_info.append({
            "Address": add,
            "Price": price,
            "Beds": beds,
            "Baths": baths
        })

df_listing = pd.DataFrame(listing_info)
df_listing.head()
# Out:
# Scraping https://listing.ca/mls/?..........1..$
# Scraping https://listing.ca/mls/?..........2..$
# Scraping https://listing.ca/mls/?..........3..$
# Scraping https://listing.ca/mls/?..........4..$
# Scraping https://listing.ca/mls/?..........5..$
# Scraping https://listing.ca/mls/?..........6..$
# Scraping https://listing.ca/mls/?..........7..$
# Scraping https://listing.ca/mls/?..........8..$
# Scraping https://listing.ca/mls/?..........9..$
# Scraping https://listing.ca/mls/?..........10..$
# Scraping https://listing.ca/mls/?..........11..$
# Scraping https://listing.ca/mls/?..........12..$
# Scraping https://listing.ca/mls/?..........13..$
# Scraping https://listing.ca/mls/?..........14..$
# Scraping https://listing.ca/mls/?..........15..$
# Scraping https://listing.ca/mls/?..........16..$
# Scraping https://listing.ca/mls/?..........17..$
# Scraping https://listing.ca/mls/?..........18..$
# Scraping https://listing.ca/mls/?..........19..$
# Scraping https://listing.ca/mls/?..........20..$
# Scraping https://listing.ca/mls/?..........21..$
# Scraping https://listing.ca/mls/?..........22..$
# Scraping https://listing.ca/mls/?..........23..$
# Scraping https://listing.ca/mls/?..........24..$
# Scraping https://listing.ca/mls/?..........25..$
# Scraping https://listing.ca/mls/?..........26..$
# Scraping https://listing.ca/mls/?..........27..$
# Scraping https://listing.ca/mls/?..........28..$
# Scraping https://listing.ca/mls/?..........29..$
# Scraping https://listing.ca/mls/?..........30..$
# Scraping https://listing.ca/mls/?..........31..$
# Scraping https://listing.ca/mls/?..........32..$
# Scraping https://listing.ca/mls/?..........33..$
# Scraping https://listing.ca/mls/?..........34..$
# Scraping https://listing.ca/mls/?..........35..$
# Scraping https://listing.ca/mls/?..........36..$
# Scraping https://listing.ca/mls/?..........37..$
# Scraping https://listing.ca/mls/?..........38..$
# Scraping https://listing.ca/mls/?..........39..$
# Scraping https://listing.ca/mls/?..........40..$
# Scraping https://listing.ca/mls/?..........41..$
# Scraping https://listing.ca/mls/?..........42..$
# Scraping https://listing.ca/mls/?..........43..$
# Scraping https://listing.ca/mls/?..........44..$
# Scraping https://listing.ca/mls/?..........45..$
# Scraping https://listing.ca/mls/?..........46..$
# Scraping https://listing.ca/mls/?..........47..$
# Scraping https://listing.ca/mls/?..........48..$
# Scraping https://listing.ca/mls/?..........49..$
# Scraping https://listing.ca/mls/?..........50..$
# Scraping https://listing.ca/mls/?..........51..$
# Scraping https://listing.ca/mls/?..........52..$
# Scraping https://listing.ca/mls/?..........53..$
# Scraping https://listing.ca/mls/?..........54..$
# Scraping https://listing.ca/mls/?..........55..$
# Scraping https://listing.ca/mls/?..........56..$
# Scraping https://listing.ca/mls/?..........57..$
# Scraping https://listing.ca/mls/?..........58..$
# Scraping https://listing.ca/mls/?..........59..$
# Scraping https://listing.ca/mls/?..........60..$
# Scraping https://listing.ca/mls/?..........61..$
# Scraping https://listing.ca/mls/?..........62..$
# Scraping https://listing.ca/mls/?..........63..$
# Scraping https://listing.ca/mls/?..........64..$
# Scraping https://listing.ca/mls/?..........65..$
# Scraping https://listing.ca/mls/?..........66..$
# Scraping https://listing.ca/mls/?..........67..$
# Scraping https://listing.ca/mls/?..........68..$
# Scraping https://listing.ca/mls/?..........69..$
# Scraping https://listing.ca/mls/?..........70..$
# Scraping https://listing.ca/mls/?..........71..$
# Scraping https://listing.ca/mls/?..........72..$
# Scraping https://listing.ca/mls/?..........73..$
# Scraping https://listing.ca/mls/?..........74..$
# Scraping https://listing.ca/mls/?..........75..$
# Scraping https://listing.ca/mls/?..........76..$
# Scraping https://listing.ca/mls/?..........77..$
# Scraping https://listing.ca/mls/?..........78..$
# Scraping https://listing.ca/mls/?..........79..$
# Scraping https://listing.ca/mls/?..........80..$
# Scraping https://listing.ca/mls/?..........81..$
# Scraping https://listing.ca/mls/?..........82..$
# Scraping https://listing.ca/mls/?..........83..$
# Scraping https://listing.ca/mls/?..........84..$
# Scraping https://listing.ca/mls/?..........85..$
# Scraping https://listing.ca/mls/?..........86..$
# Scraping https://listing.ca/mls/?..........87..$
# Scraping https://listing.ca/mls/?..........88..$
# Scraping https://listing.ca/mls/?..........89..$
# Scraping https://listing.ca/mls/?..........90..$
# Scraping https://listing.ca/mls/?..........91..$
# Scraping https://listing.ca/mls/?..........92..$
# Scraping https://listing.ca/mls/?..........93..$
# Scraping https://listing.ca/mls/?..........94..$
# Scraping https://listing.ca/mls/?..........95..$
# Scraping https://listing.ca/mls/?..........96..$
# Scraping https://listing.ca/mls/?..........97..$
# Scraping https://listing.ca/mls/?..........98..$
# Scraping https://listing.ca/mls/?..........99..$
# Scraping https://listing.ca/mls/?..........100..$
# Scraping https://listing.ca/mls/?..........101..$
# Scraping https://listing.ca/mls/?..........102..$
# Scraping https://listing.ca/mls/?..........103..$
# Scraping https://listing.ca/mls/?..........104..$
# Scraping https://listing.ca/mls/?..........105..$
# Scraping https://listing.ca/mls/?..........106..$
# Scraping https://listing.ca/mls/?..........107..$
# Scraping https://listing.ca/mls/?..........108..$
# Scraping https://listing.ca/mls/?..........109..$
# Scraping https://listing.ca/mls/?..........110..$
# Scraping https://listing.ca/mls/?..........111..$
# Scraping https://listing.ca/mls/?..........112..$
# Scraping https://listing.ca/mls/?..........113..$
# Scraping https://listing.ca/mls/?..........114..$
# Scraping https://listing.ca/mls/?..........115..$
# Scraping https://listing.ca/mls/?..........116..$
# Scraping https://listing.ca/mls/?..........117..$
# Scraping https://listing.ca/mls/?..........118..$
# Scraping https://listing.ca/mls/?..........119..$
# Scraping https://listing.ca/mls/?..........120..$
# Scraping https://listing.ca/mls/?..........121..$
# Scraping https://listing.ca/mls/?..........122..$
# Scraping https://listing.ca/mls/?..........123..$
# Scraping https://listing.ca/mls/?..........124..$
# Scraping https://listing.ca/mls/?..........125..$
# Scraping https://listing.ca/mls/?..........126..$
# Scraping https://listing.ca/mls/?..........127..$
# Scraping https://listing.ca/mls/?..........128..$
# Scraping https://listing.ca/mls/?..........129..$
# Scraping https://listing.ca/mls/?..........130..$
# Scraping https://listing.ca/mls/?..........131..$
# Scraping https://listing.ca/mls/?..........132..$
# Scraping https://listing.ca/mls/?..........133..$
# Scraping https://listing.ca/mls/?..........134..$
# Scraping https://listing.ca/mls/?..........135..$
# Scraping https://listing.ca/mls/?..........136..$
# Scraping https://listing.ca/mls/?..........137..$
# Scraping https://listing.ca/mls/?..........138..$
# Scraping https://listing.ca/mls/?..........139..$
# Scraping https://listing.ca/mls/?..........140..$
# Scraping https://listing.ca/mls/?..........141..$
# Scraping https://listing.ca/mls/?..........142..$
# Scraping https://listing.ca/mls/?..........143..$
# Scraping https://listing.ca/mls/?..........144..$
# Scraping https://listing.ca/mls/?..........145..$
# Scraping https://listing.ca/mls/?..........146..$
# Scraping https://listing.ca/mls/?..........147..$
# Scraping https://listing.ca/mls/?..........148..$
# Scraping https://listing.ca/mls/?..........149..$
# Scraping https://listing.ca/mls/?..........150..$
# Scraping https://listing.ca/mls/?..........151..$
# Scraping https://listing.ca/mls/?..........152..$
# Scraping https://listing.ca/mls/?..........153..$
# Scraping https://listing.ca/mls/?..........154..$
# Scraping https://listing.ca/mls/?..........155..$
# Scraping https://listing.ca/mls/?..........156..$
# Scraping https://listing.ca/mls/?..........157..$
# Scraping https://listing.ca/mls/?..........158..$
# Scraping https://listing.ca/mls/?..........159..$
# Scraping https://listing.ca/mls/?..........160..$
# Scraping https://listing.ca/mls/?..........161..$
# Scraping https://listing.ca/mls/?..........162..$
# Scraping https://listing.ca/mls/?..........163..$
# Scraping https://listing.ca/mls/?..........164..$
# Scraping https://listing.ca/mls/?..........165..$
# Scraping https://listing.ca/mls/?..........166..$
# Scraping https://listing.ca/mls/?..........167..$
# Scraping https://listing.ca/mls/?..........168..$
# Scraping https://listing.ca/mls/?..........169..$
# Scraping https://listing.ca/mls/?..........170..$
# Scraping https://listing.ca/mls/?..........171..$
# Scraping https://listing.ca/mls/?..........172..$
# Scraping https://listing.ca/mls/?..........173..$
# Scraping https://listing.ca/mls/?..........174..$
# Scraping https://listing.ca/mls/?..........175..$
# Scraping https://listing.ca/mls/?..........176..$
# Scraping https://listing.ca/mls/?..........177..$
# Scraping https://listing.ca/mls/?..........178..$
# Scraping https://listing.ca/mls/?..........179..$
# Scraping https://listing.ca/mls/?..........180..$
# Scraping https://listing.ca/mls/?..........181..$
# Scraping https://listing.ca/mls/?..........182..$
# Scraping https://listing.ca/mls/?..........183..$
# Scraping https://listing.ca/mls/?..........184..$
# Scraping https://listing.ca/mls/?..........185..$
# Scraping https://listing.ca/mls/?..........186..$
# Scraping https://listing.ca/mls/?..........187..$
# Scraping https://listing.ca/mls/?..........188..$
# Scraping https://listing.ca/mls/?..........189..$
# Scraping https://listing.ca/mls/?..........190..$
# Scraping https://listing.ca/mls/?..........191..$
# Scraping https://listing.ca/mls/?..........192..$
# Scraping https://listing.ca/mls/?..........193..$
# Scraping https://listing.ca/mls/?..........194..$
# Scraping https://listing.ca/mls/?..........195..$
# Scraping https://listing.ca/mls/?..........196..$
# Scraping https://listing.ca/mls/?..........197..$
# Scraping https://listing.ca/mls/?..........198..$
# Scraping https://listing.ca/mls/?..........199..$
#                         Address           Price      Beds    Baths
# 0  2323 Confederation Pkwy 1102    $430,000 CAD    2 beds  2 baths
# 1         816 Lansdowne Ave 411    $598,000 CAD  1+1 beds  1 baths
# 2               3878 Highway 35    $529,900 CAD  4+2 beds  3 baths
# 3               710 Rosebank Rd    $899,900 CAD    0 beds  0 baths
# 4        219 Major Mackenzie Dr  $5,999,999 CAD    0 beds  0 baths

# %%
df_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3973 entries, 0 to 3972
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Address  3973 non-null   object
#  1   Price    3973 non-null   object
#  2   Beds     3973 non-null   object
#  3   Baths    3973 non-null   object
# dtypes: object(4)
# memory usage: 124.3+ KB

# %%
# Out:
# Scraping https://listing.ca/mls/?..........29..$
#                 Address           Price      Beds    Baths
# 613    13 Eastfield Crt    $699,900 CAD    3 beds  2 baths
# 614   437 Wellington St    $449,900 CAD    2 beds  1 baths
# 615  185 Washington Ave    $749,900 CAD    3 beds  2 baths
# 616      1584 Centre Rd  $6,988,000 CAD  4+2 beds  6 baths
# 617      151 Tuxedo Ave    $799,900 CAD  4+2 beds  3 baths

# %%
# Out:
# Scraping https://listing.ca/mls/?..........1..$
# [{'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '190 Borough Dr 710',
#   'Price': '$659,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '49 Geranium Cres',
#   'Price': '$1,599,999 CAD',
#   'Beds': '5+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '26 Linda Way',
#   'Price': '$968,000 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '6 Evangelista Crt',
#   'Price': '$1,295,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1 Brown Rd',
#   'Price': '$299,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '107 Meadow Dr',
#   'Price': '$899,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '2009 Delaney Dr',
#   'Price': '$1,550,000 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '9 Ray St',
#   'Price': '$998,000 CAD',
#   'Beds': '3+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '12 Thackery Dr',
#   'Price': '$998,999 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '8 Clairtrell Rd',
#   'Price': '$1,468,000 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '408 Browns Line 201',
#   'Price': '$980,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '5 Massey Sq 1101',
#   'Price': '$399,900 CAD',
#   'Beds': '1 beds',
#   'Baths': '1 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '1005 King St 701',
#   'Price': '$799,900 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '150 Carroll St',
#   'Price': '$699,900 CAD',
#   'Beds': '2 beds',
#   'Baths': '1 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '59 Kenpark Ave',
#   'Price': '$1,995,000 CAD',
#   'Beds': '6+3 beds',
#   'Baths': '6 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Yellow Pine Rd',
#   'Price': '$1,899,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '5 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '3 Wallwins Way',
#   'Price': '$799,000 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '83 Mantz Cres',
#   'Price': '$899,900 CAD',
#   'Beds': '3 beds',
#   'Baths': '4 baths'},
#  {'Address': '2323 Confederation Pkwy 1102',
#   'Price': '$430,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '3878 Highway 35',
#   'Price': '$529,900 CAD',
#   'Beds': '4+2 beds',
#   'Baths': '3 baths'},
#  {'Address': '710 Rosebank Rd',
#   'Price': '$899,900 CAD',
#   'Beds': '0 beds',
#   'Baths': '0 baths'},
#  {'Address': '219 Major Mackenzie Dr',
#   'Price': '$5,999,999 CAD',
#   'Beds': '0 beds',
#   'Baths': '0 baths'},
#  {'Address': '123 Woodbine Ave 315',
#   'Price': '$489,999 CAD',
#   'Beds': '0 beds',
#   'Baths': '1 baths'},
#  {'Address': '535 Vaughan Rd',
#   'Price': '$1,026,000 CAD',
#   'Beds': '0 beds',
#   'Baths': '0 baths'},
#  {'Address': '288 Schooley Rd',
#   'Price': '$698,888 CAD',
#   'Beds': '3 beds',
#   'Baths': '2 baths'},
#  {'Address': '440 Bonny Meadow Rd',
#   'Price': '$2,249,000 CAD',
#   'Beds': '4+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '2096 Mayflower Blvd',
#   'Price': '$1,799,900 CAD',
#   'Beds': '4+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '89 Walkem Dr',
#   'Price': '$1,099,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '3 baths'},
#  {'Address': '80 Sprucewood Dr',
#   'Price': '$3,488,000 CAD',
#   'Beds': '4+3 beds',
#   'Baths': '4 baths'},
#  {'Address': '27 Tamara Dr',
#   'Price': '$1,699,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '31 Sesame St',
#   'Price': '$1,399,900 CAD',
#   'Beds': '4+4 beds',
#   'Baths': '4 baths'},
#  {'Address': '31 Sesame St',
#   'Price': '$1,399,900 CAD',
#   'Beds': '4+4 beds',
#   'Baths': '4 baths'},
#  {'Address': '2208 Chevron Prince Path Path',
#   'Price': '$799,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '102 Harlandale Ave',
#   'Price': '$3,498,000 CAD',
#   'Beds': '4+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '17 Baroness Cres',
#   'Price': '$1,388,000 CAD',
#   'Beds': '3+3 beds',
#   'Baths': '3 baths'},
#  {'Address': '19 Bobwhite Cres',
#   'Price': '$2,490,000 CAD',
#   'Beds': '5 beds',
#   'Baths': '5 baths'},
#  {'Address': '400 Webb Dr 1107',
#   'Price': '$668,800 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'Address': '2323 Confederation Pkwy 1102',
#   'Price': '$430,000 CAD',
#   'Beds': '2 beds',
#   'Baths': '2 baths'},
#  {'Address': '816 Lansdowne Ave 411',
#   'Price': '$598,000 CAD',
#   'Beds': '1+1 beds',
#   'Baths': '1 baths'},
#  {'Address': '3878 Highway 35',
#   'Price': '$529,900 CAD',
#   'Beds': '4+2 beds',
#   'Baths': '3 baths'},
#  {'Address': '710 Rosebank Rd',
#   'Price': '$899,900 CAD',
#   'Beds': '0 beds',
#   'Baths': '0 baths'},
#  {'Address': '219 Major Mackenzie Dr',
#   'Price': '$5,999,999 CAD',
#   'Beds': '0 beds',
#   'Baths': '0 baths'},
#  {'Address': '123 Woodbine Ave 315',
#   'Price': '$489,999 CAD',
#   'Beds': '0 beds',
#   'Baths': '1 baths'},
#  {'Address': '535 Vaughan Rd',
#   'Price': '$1,026,000 CAD',
#   'Beds': '0 beds',
#   'Baths': '0 baths'},
#  {'Address': '288 Schooley Rd',
#   'Price': '$698,888 CAD',
#   'Beds': '3 beds',
#   'Baths': '2 baths'},
#  {'Address': '440 Bonny Meadow Rd',
#   'Price': '$2,249,000 CAD',
#   'Beds': '4+1 beds',
#   'Baths': '4 baths'},
#  {'Address': '2096 Mayflower Blvd',
#   'Price': '$1,799,900 CAD',
#   'Beds': '4+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '89 Walkem Dr',
#   'Price': '$1,099,900 CAD',
#   'Beds': '3+1 beds',
#   'Baths': '3 baths'},
#  {'Address': '80 Sprucewood Dr',
#   'Price': '$3,488,000 CAD',
#   'Beds': '4+3 beds',
#   'Baths': '4 baths'},
#  {'Address': '27 Tamara Dr',
#   'Price': '$1,699,000 CAD',
#   'Beds': '5+2 beds',
#   'Baths': '4 baths'},
#  {'Address': '31 Sesame St',
#   'Price': '$1,399,900 CAD',
#   'Beds': '4+4 beds',
#   'Baths': '4 baths'},
#  {'Address': '31 Sesame St',
#   'Price': '$1,399,900 CAD',
#   'Beds': '4+4 beds',
#   'Baths': '4 baths'},
#  {'Address': '2208 Chevron Prince Path Path',
#   'Price': '$799,900 CAD',
#   'Beds': '4 beds',
#   'Baths': '3 baths'},
#  {'Address': '102 Harlandale Ave',
#   'Price': '$3,498,000 CAD',
#   'Beds': '4+1 beds',
#   'Baths': '6 baths'},
#  {'Address': '17 Baroness Cres',
#   'Price': '$1,388,000 CAD',
#   'Beds': '3+3 beds',
#   'Baths': '3 baths'},
#  {'Address': '19 Bobwhite Cres',
#   'Price': '$2,490,000 CAD',
#   'Beds': '5 beds',
#   'Baths': '5 baths'},
#  {'Address': '400 Webb Dr 1107',
#   'Price': '$668,800 CAD',
#   'Beds': '2+1 beds',
#   'Baths': '2 baths'},
#  {'add': '2323 Confederation Pkwy 1102'},
#  {'add': '816 Lansdowne Ave 411'},
#  {'add': '3878 Highway 35'},
#  {'add': '710 Rosebank Rd'},
#  {'add': '219 Major Mackenzie Dr'},
#  {'add': '123 Woodbine Ave 315'},
#  {'add': '535 Vaughan Rd'},
#  {'add': '288 Schooley Rd'},
#  {'add': '440 Bonny Meadow Rd'},
#  {'add': '2096 Mayflower Blvd'},
#  {'add': '89 Walkem Dr'},
#  {'add': '80 Sprucewood Dr'},
#  {'add': '27 Tamara Dr'},
#  {'add': '31 Sesame St'},
#  {'add': '31 Sesame St'},
#  {'add': '2208 Chevron Prince Path Path'},
#  {'add': '102 Harlandale Ave'},
#  {'add': '17 Baroness Cres'},
#  {'add': '19 Bobwhite Cres'},
#  {'add': '400 Webb Dr 1107'}]

# %%
# Out:
# Scraping https://listing.ca/mls/?..........28..$
# <div class="slt_address"><a href="https://hamilton.listing.ca/723-tate-ave.X5477036.htm#35-fk" style="font-size:16px;">723 Tate Ave</a></div>

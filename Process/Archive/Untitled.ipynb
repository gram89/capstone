# %%
import pgeocode
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Resources/listing_clean_with_Postal_codes_errors_removed.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                       Address    Price  Beds  \
# 0           0             0  2323 Confederation Pkwy 1102   430000     2
# 1           1             1         816 Lansdowne Ave 411   598000     2
# 2           2             6                   109 Lake St   750000     4
# 3           3             7              321 Queenston Rd  1899000     4
# 4           4             8         650 Upper Sherman Ave   899000     4
#
#    Baths                 City                                 Area  \
# 0      2          Mississauga                           Cooksville
# 1      1              Toronto  Dovercourt-Wallace Emerson-Junction
# 2      2       St. Catharines                                  NaN
# 3      4  Niagara-on-the-Lake                                  NaN
# 4      2             Hamilton                            Burkholme
#
#                Street                                        Description  \
# ...

# %%
nomi = pgeocode.Nominatim('CA')
nomi.query_postal_code("M6H 3Z6").county_name
# Out:
# 'Toronto'

# %%
postal_code = df["Postal_Code"]
city=[]
for i in range (0, len(postal_code)):
    city_extract = nomi.query_postal_code(postal_code[i]).county_name
    print(city_extract)
# Out:
# Mississauga
# Toronto
# St. Catharines
# Hamilton
# Hamilton
# Oakville
# Brampton
# Barrie
# nan
# Richmond Hill
# Scarborough
# Mississauga
# Pickering
# Mississauga
# Lake Simcoe
# Markham
# Scarborough
# Etobicoke
# Kingston
# nan
# North York
# North York
# nan
# Kitchener
# Ottawa
# Hamilton
# Guelph
# Hamilton
# Peterborough
# Mississauga
# nan
# Etobicoke
# North York
# nan
# Peterborough
# Etobicoke
# nan
# nan
# Brampton
# Halton
# Brampton
# Barrie
# Brant
# Toronto
# Toronto
# Markham
# Markham
# Bowmanville
# Scarborough
# Oshawa
# Whitby
# Ajax
# Willowdale
# North York
# Hamilton
# Waterloo
# Etobicoke
# Mississauga
# Burlington
# Etobicoke
# Toronto
# Markham
# nan
# nan
# Richmond Hill
# Scarborough
# Pickering
# Pickering
# nan
# York
# Toronto
# Toronto
# Toronto
# Mississauga
# nan
# Hamilton
# nan
# Halton
# Kingston
# Brampton
# nan
# Brampton
# Brampton
# Mississauga
# Brampton
# nan
# Brampton
# Mississauga
# Richmond Hill
# Oakville
# Sault Ste.
# Barrie
# ...
